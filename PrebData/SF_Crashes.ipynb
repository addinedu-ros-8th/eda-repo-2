# %%
import pandas as pd

# %% [markdown]
# ## Get the data (CSV) file

# %%
dataSF = pd.read_csv("../data/CrahsesSF.csv", 
                   usecols=["CASE_ID", "COLLISION_DATE", "COUNTY", "INTERSECTION", "WEATHER_1", "STATE_HWY_IND", "ROAD_SURFACE", "CONTROL_DEVICE", "PCF_VIOL_CATEGORY"])

dataSF
# Out:
#        CASE_ID COLLISION_DATE INTERSECTION WEATHER_1 STATE_HWY_IND  \
# 0      8845721     2019-03-28            Y         A             N
# 1      8857949     2019-04-12            Y         A             N
# 2      8878185     2019-05-26            N         A             N
# 3      8879843     2019-05-24            N         A             N
# 4      8900566     2019-06-09            N         A             N
# ...        ...            ...          ...       ...           ...
# 16041  9658640     2023-12-27            Y         C             N
# 16042  9659423     2023-12-13            Y         A             N
# 16043  9670930     2023-12-29            Y         C             N
# 16044  9671881     2023-12-28            N         B             N
# 16045  9679147     2023-10-04            Y         A             N
#
#       PCF_VIOL_CATEGORY ROAD_SURFACE CONTROL_DEVICE         COUNTY
# 0                    04            A              D  SAN FRANCISCO
# ...

# %% [markdown]
# ## Replace ABCDE to our index (012345)

# %%
dataSF["WEATHER_1"] = dataSF["WEATHER_1"].replace("A", 0)
dataSF["WEATHER_1"] = dataSF["WEATHER_1"].replace("B", 1)
dataSF["WEATHER_1"] = dataSF["WEATHER_1"].replace("C", 2)
dataSF["WEATHER_1"] = dataSF["WEATHER_1"].replace("D", 3)
dataSF["WEATHER_1"] = dataSF["WEATHER_1"].replace("E", 4)
dataSF["WEATHER_1"] = dataSF["WEATHER_1"].replace("F", 4)
dataSF["WEATHER_1"] = dataSF["WEATHER_1"].replace("-", 4)
dataSF["WEATHER_1"] = dataSF["WEATHER_1"].replace("G", 4)

dataSF["ROAD_SURFACE"] = dataSF["ROAD_SURFACE"].replace("A", 0)
dataSF["ROAD_SURFACE"] = dataSF["ROAD_SURFACE"].replace("B", 1)
dataSF["ROAD_SURFACE"] = dataSF["ROAD_SURFACE"].replace("C", 2)
dataSF["ROAD_SURFACE"] = dataSF["ROAD_SURFACE"].replace("D", 3)
dataSF["ROAD_SURFACE"] = dataSF["ROAD_SURFACE"].replace("-", 3)
dataSF["ROAD_SURFACE"] = dataSF["ROAD_SURFACE"].replace("H", 3)

dataSF["PCF_VIOL_CATEGORY"] = dataSF["PCF_VIOL_CATEGORY"].replace("01", 6)
dataSF["PCF_VIOL_CATEGORY"] = dataSF["PCF_VIOL_CATEGORY"].replace("02", 8)
dataSF["PCF_VIOL_CATEGORY"] = dataSF["PCF_VIOL_CATEGORY"].replace("03", 2)
dataSF["PCF_VIOL_CATEGORY"] = dataSF["PCF_VIOL_CATEGORY"].replace("04", 2)
dataSF["PCF_VIOL_CATEGORY"] = dataSF["PCF_VIOL_CATEGORY"].replace("05", 0)
dataSF["PCF_VIOL_CATEGORY"] = dataSF["PCF_VIOL_CATEGORY"].replace("06", 1)
dataSF["PCF_VIOL_CATEGORY"] = dataSF["PCF_VIOL_CATEGORY"].replace("07", 1)
dataSF["PCF_VIOL_CATEGORY"] = dataSF["PCF_VIOL_CATEGORY"].replace("08", 3)
dataSF["PCF_VIOL_CATEGORY"] = dataSF["PCF_VIOL_CATEGORY"].replace("09", 8)
dataSF["PCF_VIOL_CATEGORY"] = dataSF["PCF_VIOL_CATEGORY"].replace("10", 8)
dataSF["PCF_VIOL_CATEGORY"] = dataSF["PCF_VIOL_CATEGORY"].replace("11", 8)
dataSF["PCF_VIOL_CATEGORY"] = dataSF["PCF_VIOL_CATEGORY"].replace("12", 9)
dataSF["PCF_VIOL_CATEGORY"] = dataSF["PCF_VIOL_CATEGORY"].replace("13", 5)
dataSF["PCF_VIOL_CATEGORY"] = dataSF["PCF_VIOL_CATEGORY"].replace("14", 8)
dataSF["PCF_VIOL_CATEGORY"] = dataSF["PCF_VIOL_CATEGORY"].replace("15", 8)
dataSF["PCF_VIOL_CATEGORY"] = dataSF["PCF_VIOL_CATEGORY"].replace("16", 8)
dataSF["PCF_VIOL_CATEGORY"] = dataSF["PCF_VIOL_CATEGORY"].replace("17", 8)
dataSF["PCF_VIOL_CATEGORY"] = dataSF["PCF_VIOL_CATEGORY"].replace("18", 8)
dataSF["PCF_VIOL_CATEGORY"] = dataSF["PCF_VIOL_CATEGORY"].replace("19", 8)
dataSF["PCF_VIOL_CATEGORY"] = dataSF["PCF_VIOL_CATEGORY"].replace("20", 8)
dataSF["PCF_VIOL_CATEGORY"] = dataSF["PCF_VIOL_CATEGORY"].replace("21", 8)
dataSF["PCF_VIOL_CATEGORY"] = dataSF["PCF_VIOL_CATEGORY"].replace("22", 8)
dataSF["PCF_VIOL_CATEGORY"] = dataSF["PCF_VIOL_CATEGORY"].replace("23", 8)
dataSF["PCF_VIOL_CATEGORY"] = dataSF["PCF_VIOL_CATEGORY"].replace("24", 7)
dataSF["PCF_VIOL_CATEGORY"] = dataSF["PCF_VIOL_CATEGORY"].replace("00", 8)
dataSF["PCF_VIOL_CATEGORY"] = dataSF["PCF_VIOL_CATEGORY"].replace("- ", 8)

dataSF
# Out:
# /tmp/ipykernel_11954/2416187855.py:8: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   dataSF["WEATHER_1"] = dataSF["WEATHER_1"].replace("G", 4)
# /tmp/ipykernel_11954/2416187855.py:15: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   dataSF["ROAD_SURFACE"] = dataSF["ROAD_SURFACE"].replace("H", 3)
# ...

# %% [markdown]
# ## Remake with proper columns & type to save into Data Base

# %%
data = pd.DataFrame(columns=["accident_id", "accident_date", "speed",  "age", "sex", "auto_id",  "state_id", "weather_id",
                             "road_id", "movement_id", "brand_id","pavement_id"])

data.accident_id = dataSF["CASE_ID"]      
data.state_id = 1
data.accident_date = dataSF["COLLISION_DATE"]
data.auto_id = 1
data.brand_id = None
data.weather_id = dataSF["WEATHER_1"]
data.pavement_id = dataSF["ROAD_SURFACE"]
data.movement_id = dataSF["PCF_VIOL_CATEGORY"]
data.speed = None
data.age = None
data.sex = None
data.road_id =  dataSF.apply(lambda row: '2' if row['INTERSECTION'] == 'Y' 
                         else ('1' if row['STATE_HWY_IND'] == 'Y' 
                               else '0'), axis=1)
data
# Out:
#        accident_id accident_date speed   age   sex  auto_id  state_id  \
# 0          8845721    2019-03-28  None  None  None        1         1
# 1          8857949    2019-04-12  None  None  None        1         1
# 2          8878185    2019-05-26  None  None  None        1         1
# 3          8879843    2019-05-24  None  None  None        1         1
# 4          8900566    2019-06-09  None  None  None        1         1
# ...            ...           ...   ...   ...   ...      ...       ...
# 16041      9658640    2023-12-27  None  None  None        1         1
# 16042      9659423    2023-12-13  None  None  None        1         1
# 16043      9670930    2023-12-29  None  None  None        1         1
# 16044      9671881    2023-12-28  None  None  None        1         1
# 16045      9679147    2023-10-04  None  None  None        1         1
#
#        weather_id road_id  movement_id brand_id  pavement_id
# 0               0       2            2     None            0
# ...

# %%
data = data.drop(columns=["accident_id"])

# %%
data.head(5)
# Out:
#   accident_date speed   age   sex  auto_id  state_id  weather_id road_id  \
# 0    2019-03-28  None  None  None        1         1           0       2
# 1    2019-04-12  None  None  None        1         1           0       2
# 2    2019-05-26  None  None  None        1         1           0       0
# 3    2019-05-24  None  None  None        1         1           0       0
# 4    2019-06-09  None  None  None        1         1           0       0
#
#    movement_id brand_id  pavement_id
# 0            2     None            0
# 1            0     None            0
# 2            2     None            0
# 3            3     None            0
# 4            2     None            0

# %% [markdown]
# ### Fixed data type

# %%
data['weather_id'] = data['weather_id'].astype(int)
data['road_id'] = data['road_id'].astype(int)
data['movement_id'] = data['movement_id'].astype(int)
#data['brand_id'] = data['brand_id'].astype(int)
data['pavement_id'] = data['pavement_id'].astype(int)

# %%
data.dtypes
# Out:
# accident_date    object
# speed            object
# age              object
# sex              object
# auto_id           int64
# state_id          int64
# weather_id        int64
# road_id           int64
# movement_id       int64
# brand_id         object
# pavement_id       int64
# dtype: object

# %% [markdown]
# ## Upload to AWS

# %%
import mysql.connector

cnt = 1
remote = mysql.connector.connect(
    host = "database-eda.chuw4mu887pw.ap-northeast-2.rds.amazonaws.com",
    port = 3306,
    user = 'root',
    password = 'myung234',
    database = 'eda'
)

cursor = remote.cursor(buffered=True)

sql = """
INSERT INTO car_accident (
    accident_date, speed, age, sex, auto_id, state_id, 
    weather_id, road_id, movement_id, brand_id, pavement_id
) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
"""

for i, row in data.iterrows():
    cursor.execute(sql, tuple(row))
    remote.commit()
    print("complete commit", str(cnt))
    cnt += 1

remote.close()
# Out:
# complete commit 1
# complete commit 2
# complete commit 3
# complete commit 4
# complete commit 5
# complete commit 6
# complete commit 7
# complete commit 8
# complete commit 9
# complete commit 10
# complete commit 11
# complete commit 12
# complete commit 13
# complete commit 14
# complete commit 15
# complete commit 16
# complete commit 17
# complete commit 18
# complete commit 19
# complete commit 20
# complete commit 21
# complete commit 22
# complete commit 23
# complete commit 24
# complete commit 25
# complete commit 26
# complete commit 27
# complete commit 28
# complete commit 29
# complete commit 30
# complete commit 31
# complete commit 32
# complete commit 33
# complete commit 34
# complete commit 35
# complete commit 36
# complete commit 37
# complete commit 38
# complete commit 39
# complete commit 40
# complete commit 41
# complete commit 42
# complete commit 43
# complete commit 44
# complete commit 45
# complete commit 46
# complete commit 47
# complete commit 48
# ...
