# %%
import pandas as pd

# %% [markdown]
# ## Get the data (CSV) file

# %%
dataSF = pd.read_csv("/home/jane/dev_ws/EDA/src/testIpynb/Crashes.csv", 
                   usecols=["CASE_ID", "COLLISION_DATE", "COUNTY", "INTERSECTION", "WEATHER_1", "STATE_HWY_IND", "ROAD_SURFACE", "LIGHTING", "CONTROL_DEVICE", 
                            "ALCOHOL_INVOLVED"])

dataSF
# Out:
#        CASE_ID COLLISION_DATE INTERSECTION WEATHER_1 STATE_HWY_IND  \
# 0      8845721     2019-03-28            Y         A             N
# 1      8857949     2019-04-12            Y         A             N
# 2      8878185     2019-05-26            N         A             N
# 3      8879843     2019-05-24            N         A             N
# 4      8900566     2019-06-09            N         A             N
# ...        ...            ...          ...       ...           ...
# 17539  9728940     2024-06-30            Y         A             N
# 17540  9728950     2024-06-28            Y         A             N
# 17541  9729767     2024-03-15            N         A             N
# 17542  9731523     2024-06-29            Y         A             N
# 17543  9734536     2024-06-06            Y         A             N
#
#       ROAD_SURFACE LIGHTING CONTROL_DEVICE ALCOHOL_INVOLVED         COUNTY
# 0                A        C              D              NaN  SAN FRANCISCO
# 1                A        A              D              NaN  SAN FRANCISCO
# 2                A        A              D              NaN  SAN FRANCISCO
# 3                A        C              A              NaN  SAN FRANCISCO
# 4                A        A              A              NaN  SAN FRANCISCO
# ...            ...      ...            ...              ...            ...
# 17539            A        A              A              NaN  SAN FRANCISCO
# 17540            A        A              A              NaN  SAN FRANCISCO
# 17541            A        A              D              NaN  SAN FRANCISCO
# 17542            A        A              A                Y  SAN FRANCISCO
# 17543            A        A              D              NaN  SAN FRANCISCO
#
# [17544 rows x 10 columns]

# %% [markdown]
# ## Replace ABCDE to our index (012345)

# %%
dataSF["WEATHER_1"] = dataSF["WEATHER_1"].replace("A", 0)
dataSF["WEATHER_1"] = dataSF["WEATHER_1"].replace("B", 1)
dataSF["WEATHER_1"] = dataSF["WEATHER_1"].replace("C", 2)
dataSF["WEATHER_1"] = dataSF["WEATHER_1"].replace("D", 3)
dataSF["WEATHER_1"] = dataSF["WEATHER_1"].replace("E", 4)
dataSF["WEATHER_1"] = dataSF["WEATHER_1"].replace("F", 4)


dataSF["ROAD_SURFACE"] = dataSF["ROAD_SURFACE"].replace("A", 0)
dataSF["ROAD_SURFACE"] = dataSF["ROAD_SURFACE"].replace("B", 1)
dataSF["ROAD_SURFACE"] = dataSF["ROAD_SURFACE"].replace("C", 2)
dataSF["ROAD_SURFACE"] = dataSF["ROAD_SURFACE"].replace("D", 3)

dataSF["ALCOHOL_INVOLVED"] = dataSF["ALCOHOL_INVOLVED"].replace("Y", True)
dataSF
# Out:
#        CASE_ID COLLISION_DATE INTERSECTION WEATHER_1 STATE_HWY_IND  \
# 0      8845721     2019-03-28            Y         0             N
# 1      8857949     2019-04-12            Y         0             N
# 2      8878185     2019-05-26            N         0             N
# 3      8879843     2019-05-24            N         0             N
# 4      8900566     2019-06-09            N         0             N
# ...        ...            ...          ...       ...           ...
# 17539  9728940     2024-06-30            Y         0             N
# 17540  9728950     2024-06-28            Y         0             N
# 17541  9729767     2024-03-15            N         0             N
# 17542  9731523     2024-06-29            Y         0             N
# 17543  9734536     2024-06-06            Y         0             N
#
#       ROAD_SURFACE LIGHTING CONTROL_DEVICE ALCOHOL_INVOLVED         COUNTY
# 0                0        C              D              NaN  SAN FRANCISCO
# 1                0        A              D              NaN  SAN FRANCISCO
# 2                0        A              D              NaN  SAN FRANCISCO
# 3                0        C              A              NaN  SAN FRANCISCO
# 4                0        A              A              NaN  SAN FRANCISCO
# ...            ...      ...            ...              ...            ...
# 17539            0        A              A              NaN  SAN FRANCISCO
# 17540            0        A              A              NaN  SAN FRANCISCO
# 17541            0        A              D              NaN  SAN FRANCISCO
# 17542            0        A              A             True  SAN FRANCISCO
# 17543            0        A              D              NaN  SAN FRANCISCO
#
# [17544 rows x 10 columns]

# %% [markdown]
# ## Remake with proper columns & type to save into Data Base

# %%
data = pd.DataFrame(columns=["accident_id", "accident_date", "alcohol", "speed",  "age", "sex", "auto_id",  "state_id", "weather_id",
                             "road_id", "movement_id", "brand_id","pavement_id"])


data.accident_id = dataSF["CASE_ID"]
data.state_id = "1"
data.accident_date = dataSF["COLLISION_DATE"]
data.auto_id = "1"
data.brand_id= None
data.weather_id = dataSF["WEATHER_1"]

data.pavement_id = dataSF["ROAD_SURFACE"]
data.movement_id 
data.speed 
data.age 
data.sex 
data.alcohol = dataSF["ALCOHOL_INVOLVED"]


data.road_id =  dataSF.apply(lambda row: '2' if row['INTERSECTION'] == 'Y' 
                         else ('1' if row['STATE_HWY_IND'] == 'Y' 
                               else '0'), axis=1)


data["alcohol"] = data["alcohol"].fillna(False)

data
# Out:
# /tmp/ipykernel_41982/1613741599.py:25: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data["alcohol"] = data["alcohol"].fillna(False)
#        accident_id accident_date  alcohol speed  age  sex auto_id state_id  \
# 0          8845721    2019-03-28    False   NaN  NaN  NaN       1        1
# 1          8857949    2019-04-12    False   NaN  NaN  NaN       1        1
# 2          8878185    2019-05-26    False   NaN  NaN  NaN       1        1
# 3          8879843    2019-05-24    False   NaN  NaN  NaN       1        1
# 4          8900566    2019-06-09    False   NaN  NaN  NaN       1        1
# ...            ...           ...      ...   ...  ...  ...     ...      ...
# 17539      9728940    2024-06-30    False   NaN  NaN  NaN       1        1
# 17540      9728950    2024-06-28    False   NaN  NaN  NaN       1        1
# 17541      9729767    2024-03-15    False   NaN  NaN  NaN       1        1
# 17542      9731523    2024-06-29     True   NaN  NaN  NaN       1        1
# 17543      9734536    2024-06-06    False   NaN  NaN  NaN       1        1
#
#       weather_id road_id movement_id brand_id pavement_id
# 0              0       2         NaN     None           0
# 1              0       2         NaN     None           0
# 2              0       0         NaN     None           0
# 3              0       0         NaN     None           0
# 4              0       0         NaN     None           0
# ...          ...     ...         ...      ...         ...
# 17539          0       2         NaN     None           0
# 17540          0       2         NaN     None           0
# 17541          0       0         NaN     None           0
# 17542          0       2         NaN     None           0
# 17543          0       2         NaN     None           0
#
# [17544 rows x 13 columns]

# %% [markdown]
# ### !! NEED TO REVISE DATA TYPES

# %%
data.dtypes
# Out:
# accident_id       int64
# accident_date    object
# alcohol            bool
# speed            object
# age              object
# sex              object
# auto_id          object
# state_id         object
# weather_id       object
# road_id          object
# movement_id      object
# brand_id         object
# pavement_id      object
# dtype: object

# %% [markdown]
# ## Upload to AWS

# %%
import mysql.connector

# %%
remote = mysql.connector.connect(
    host = "database-eda.chuw4mu887pw.ap-northeast-2.rds.amazonaws.com",
    port = 3306,
    user = 'root',
    password = 'myung234',
    database = 'eda'
)

cursor = remote.cursor(buffered=True)

sql = "Insert into car_accident Values (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)"

for i, row in data.iterrows():
    cursor.execute(sql, tuple(row))
    print(tuple(row))
    remote.commit()
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File ~/venv/eda_venv/lib/python3.10/site-packages/mysql/connector/connection_cext.py:706, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     705         query = query.encode("utf-8")
# --> 706     self._cmysql.query(
#     707         query,
#     708         raw=raw,
#     709         buffered=buffered,
#     710         raw_as_string=raw_as_string,
#     711         query_attrs=self.query_attrs,
#     712     )
#     713 except MySQLInterfaceError as err:
#
# MySQLInterfaceError: Unknown column 'nan' in 'field list'
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# Cell In[9], line 14
#      11 sql = "Insert into car_accident Values (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)"
#      13 for i, row in data.iterrows():
# ---> 14     cursor.execute(sql, tuple(row))
#      15     print(tuple(row))
#      16     remote.commit()
#
# File ~/venv/eda_venv/lib/python3.10/site-packages/mysql/connector/cursor_cext.py:357, in CMySQLCursor.execute(self, operation, params, multi)
#     352             raise ProgrammingError(
#     353                 "Not all parameters were used in the SQL statement"
#     354             )
#     356 try:
# --> 357     result = self._connection.cmd_query(
#     358         stmt,
#     359         raw=self._raw,
#     360         buffered=self._buffered,
#     361         raw_as_string=self._raw_as_string,
#     362     )
#     363 except MySQLInterfaceError as err:
#     364     raise get_mysql_exception(
#     365         msg=err.msg, errno=err.errno, sqlstate=err.sqlstate
#     366     ) from err
#
# File ~/venv/eda_venv/lib/python3.10/site-packages/mysql/connector/opentelemetry/context_propagation.py:97, in with_context_propagation.<locals>.wrapper(cnx, *args, **kwargs)
#      95 # pylint: disable=possibly-used-before-assignment
#      96 if not OTEL_ENABLED or not cnx.otel_context_propagation:
# ---> 97     return method(cnx, *args, **kwargs)
#      99 current_span = trace.get_current_span()
#     100 tp_header = None
#
# File ~/venv/eda_venv/lib/python3.10/site-packages/mysql/connector/connection_cext.py:714, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     706     self._cmysql.query(
#     707         query,
#     708         raw=raw,
#    (...)
#     711         query_attrs=self.query_attrs,
#     712     )
#     713 except MySQLInterfaceError as err:
# --> 714     raise get_mysql_exception(
#     715         err.errno, msg=err.msg, sqlstate=err.sqlstate
#     716     ) from err
#     717 except AttributeError as err:
#     718     addr = (
#     719         self._unix_socket if self._unix_socket else f"{self._host}:{self._port}"
#     720     )
#
# ProgrammingError: 1054 (42S22): Unknown column 'nan' in 'field list'
